# %%
import pickle

sc=pickle.load(open('FWI_scaler.pkl','rb'))
model=pickle.load(open('FWI_model.pkl','rb'))

# %%
Unknown_data = {
    'Temperature':[29,30,33],
    'RH':[57,88,65],
    'Ws':[18,10,12],
    'Rain':[0,0.8,5.2],
    'ISI':[1.3,2.5,9.1],
    'BUI':[3.4,10.5,15.0],
    'FWI':[0.5,10,12],
    'Region':[0,1,1]
}

# %%
import pandas as pd
df1= pd.DataFrame(Unknown_data)

# %%
df1
# Out:
#    Temperature  RH  Ws  Rain  ISI   BUI   FWI  Region
# 0           29  57  18   0.0  1.3   3.4   0.5       0
# 1           30  88  10   0.8  2.5  10.5  10.0       1
# 2           33  65  12   5.2  9.1  15.0  12.0       1

# %%
sc_df1=sc.transform(df1)

# %%
sc_df1
# Out:
# array([[-0.87563202, -0.32051527,  0.90552731, -0.38015572, -0.84276528,
#         -0.92744694, -0.88842984, -1.01036297],
#        [-0.60120131,  1.74770239, -2.13641726,  0.00395996, -0.56510358,
#         -0.45548277,  0.33121723,  0.98974332],
#        [ 0.22209084,  0.21321832, -1.37593111,  2.1165962 ,  0.96203577,
#         -0.15635055,  0.58798504,  0.98974332]])

# %%
model.predict(sc_df1)
# Out:
# array([0, 1, 1])
